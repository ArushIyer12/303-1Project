# %% [markdown]
# # Data Cleaning (Abby)

# %% [markdown]
# - X Dropping missing vals
# - X Converting fire/no fire to 0 and 1
# - X Converting columns to appropriate data types
# - X Converting region to 1 or 2?
# - XCreating test and training data sets

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
import sklearn
import warnings
import itertools
import time
warnings.filterwarnings('ignore')

data = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)

df = data.copy()
#dropping missing vals
df.dropna(inplace=True)

# dropping a row that was just for labelling
df = df.drop(index=123,axis=0)

# fixing index 
df.reset_index(inplace=True)

# %%
# Region 1 and 2
# Region 1 is Bejaia and Region 2 is Sidi Bel-Abbes 
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# getting rid of column names weird spacing
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#Converting Not fire/Fire (with unnecessary spacing) to 0 and 1
print(df['Classes'].unique())
# Out:
# ['not fire   ' 'fire   ' 'fire' 'fire ' 'not fire' 'not fire '
#  'not fire     ' 'not fire    ']

# %%
df.Classes=df.Classes.str.strip()
df.Classes.unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df['Classes'] = df['Classes'].replace('not fire', 0)
df['Classes'] = df['Classes'].replace('fire', 1)
df.Classes.unique()
# Out:
# array([0, 1])

# %%
# converting column data types
df['DC']=df['DC'].astype('float')
df['ISI']=df['ISI'].astype('float')
df['BUI']=df['BUI'].astype('float')
df['FWI']=df['FWI'].astype('float')
df['day']=df['day'].astype('int')
df['month']=df['month'].astype('int')
df['year']=df['year'].astype('int')
df['Temperature']=df['Temperature'].astype('int')
df['RH']=df['RH'].astype('int')
df['Ws']=df['Ws'].astype('int')
df['Rain']=df['Rain'].astype('float')
df['FFMC']=df['FFMC'].astype('float')
df['DMC']=df['DMC'].astype('float')
df
# Out:
#      index  day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  \
# 0        0    1      6  2012           29  57  18   0.0  65.7   3.4   7.6
# 1        1    2      6  2012           29  61  13   1.3  64.4   4.1   7.6
# 2        2    3      6  2012           26  82  22  13.1  47.1   2.5   7.1
# 3        3    4      6  2012           25  89  13   2.5  28.6   1.3   6.9
# 4        4    5      6  2012           27  77  16   0.0  64.8   3.0  14.2
# ..     ...  ...    ...   ...          ...  ..  ..   ...   ...   ...   ...
# 238    241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5
# 239    242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0
# 240    243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9
# 241    244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2
# 242    245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI  Classes  Region
# 0    1.3   3.4  0.5        0       1
# 1    1.0   3.9  0.4        0       1
# 2    0.3   2.7  0.1        0       1
# 3    0.0   1.7  0.0        0       1
# 4    1.2   3.9  0.5        0       1
# ..   ...   ...  ...      ...     ...
# 238  4.5  16.9  6.5        1       2
# 239  0.1   6.2  0.0        0       2
# 240  0.4   3.4  0.2        0       2
# 241  1.7   5.1  0.7        0       2
# 242  1.2   4.8  0.5        0       2
#
# [243 rows x 16 columns]

# %%
df.dtypes
# Out:
# index            int64
# day              int64
# month            int64
# year             int64
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes          int64
# Region           int64
# dtype: object

# %%
# No null values :)
df.isnull().sum()
# Out:
# index          0
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
# No duplicates :)
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

#Creating training and test datasets
np.random.seed(2)
train = df.sample(round(df.shape[0]*0.7))
test = df.drop(train.index)

# %% [markdown]
# # Exploratory Data Analysis (Mel, Abby)

# %% [markdown]
# - heatmaps
# - pairplots
# - pie chart/barplot of fire vs no fire breakdown
# - density plots of different vars
# - (other stuff)

# %% [markdown]
# # Logistic Regression Model Building (Arush, Mel)

# %% [markdown]
# - VIF for collinearity
# - Use heatmaps/pairplots in EDA section
# - Variable Selection Algorithms
# - See if we need transformations by visualizing lineplots of response vs diff vairables
# - building/printing model summary

# %%
def confusion_matrix_data(data, actual_values, model, cutoff = 0.5):
     
    # predict the values
    pred_values = model.predict(data) # these will be probabilities
    
    # Specify bins to do the cutoff thing
    bins = np.array([0, cutoff, 1])
    
    # Confusion matrix
    cm = np.histogram2d(actual_values, pred_values, bins = bins)[0]
    
    cm_df = pd.DataFrame(cm)
    cm_df.columns = ['Predicted 0','Predicted 1']
    cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
    
    accuracy = (cm[0,0]+cm[1,1])/cm.sum()
    
    fnr = (cm[1,0])/(cm[1,0]+cm[1,1])
    fpr = (cm[0,1])/(cm[0,0]+cm[0,1])
    
    precision = (cm[1,1])/(cm[1,1]+cm[0,1])
    tpr = (cm[1,1])/(cm[1,0]+cm[1,1]) # Recall
    
    # fpr_roc, tpr_roc, auc_thresholds = roc_curve(actual_values, pred_values)
    # auc_value = (auc(fpr_roc, tpr_roc))# AUC of ROC
    sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
    plt.ylabel("Actual Values")
    plt.xlabel("Predicted Values")
    print("Classification accuracy = {:.1%}".format(accuracy))
    print("Precision = {:.1%}".format(precision))
    print("TPR or Recall = {:.1%}".format(tpr))
    print("FNR = {:.1%}".format(fnr))
    print("FPR = {:.1%}".format(fpr))
    # print("ROC-AUC = {:.1%}".format(auc_value))

# %%
# VIF test
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

X = train[['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC','ISI', 'BUI', 'FWI']]

X = add_constant(X)
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

for i in range(len(X.columns)):
    vif_data.loc[i,'VIF'] = variance_inflation_factor(X.values, i)

print(vif_data)
# Out:
#         feature         VIF
# 0           day    1.548816
# 1         month    1.120089
# 2          year  482.030547
# 3   Temperature    2.347870
# 4            RH    2.785183
# 5            Ws    1.301353
# 6          Rain    1.565911
# 7          FFMC    4.986148
# 8           DMC   66.721558
# 9            DC   21.300967
# 10          ISI   53.888193
# 11          BUI  155.066601
# 12          FWI   93.763546

# %% [markdown]
# ## Variable Selection

# %% [markdown]
# ### Normal Forward Stepwise Selection

# %%
# Forward Stepwise Selection 

# Defining helpers

X = train[['Temperature','Rain','Ws','RH','FFMC','DMC','DC','ISI','BUI','FWI']]

def processSubset(predictor_subset):
    model = smf.ols('Classes~' + '+'.join(predictor_subset),data = train).fit()
    Rsquared = model.rsquared
    return {"model":model, "Rsquared":Rsquared}

def forward(predictors):

    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    tic = time.time()
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    models = pd.DataFrame(results)
    
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic), "seconds.")
    
    return best_model


def forward_selection():
    models_best = pd.DataFrame(columns=["Rsquared", "model"])

    tic = time.time()
    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best


def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    plt.subplot(2, 2, 1)

    plt.plot(models_best["Rsquared"])
    plt.xlabel('# Predictors')
    plt.ylabel('Rsquared')


    rsquared_adj = models_best.apply(lambda row: row[1].rsquared_adj, axis=1)

    plt.subplot(2, 2, 2)
    plt.plot(rsquared_adj)
    plt.plot(1+rsquared_adj.argmax(), rsquared_adj.max(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('adjusted rsquared')

    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 3)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 4)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')

# %%
models_best = forward_selection()
# Out:
# Processed  10 models on 1 predictors in 0.05488705635070801 seconds.
# Processed  9 models on 2 predictors in 0.030682802200317383 seconds.
# Processed  8 models on 3 predictors in 0.0282440185546875 seconds.
# Processed  7 models on 4 predictors in 0.02831411361694336 seconds.
# Processed  6 models on 5 predictors in 0.02650308609008789 seconds.
# Processed  5 models on 6 predictors in 0.026811838150024414 seconds.
# Processed  4 models on 7 predictors in 0.029551029205322266 seconds.
# Processed  3 models on 8 predictors in 0.019470930099487305 seconds.
# Processed  2 models on 9 predictors in 0.01584911346435547 seconds.
# Processed  1 models on 10 predictors in 0.00990605354309082 seconds.
# Total elapsed time: 0.28310608863830566 seconds.

# %%
best_sub_plots()

# %%
# Finding the best model

best_subset_model_no_interaction = models_best.loc[6,'model']
models_best.loc[6,'model'].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Classes   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     80.56
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):           3.37e-46
# Time:                        15:07:01   Log-Likelihood:                -4.2746
# No. Observations:                 170   AIC:                             22.55
# Df Residuals:                     163   BIC:                             44.50
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.2658      0.274     -8.267      0.000      -2.807      -1.725
# FFMC           0.0271      0.002     11.131      0.000       0.022       0.032
# FWI            0.0499      0.006      7.952      0.000       0.038       0.062
# RH             0.0144      0.002      7.009      0.000       0.010       0.018
# BUI           -0.0125      0.003     -4.489      0.000      -0.018      -0.007
# Ws            -0.0220      0.008     -2.705      0.008      -0.038      -0.006
# Rain           0.0258      0.011      2.323      0.021       0.004       0.048
# ==============================================================================
# Omnibus:                        1.570   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.456   Jarque-Bera (JB):                1.243
# Skew:                           0.025   Prob(JB):                        0.537
# Kurtosis:                       3.416   Cond. No.                     1.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
confusion_matrix_data(train, train.Classes, best_subset_model_no_interaction, 0.3)
# Out:
# Classification accuracy = 85.7%
# Precision = 79.8%
# TPR or Recall = 100.0%
# FNR = 0.0%
# FPR = 32.7%

# %%
confusion_matrix_data(test, test.Classes, best_subset_model_no_interaction, 0.3)
# Out:
# Classification accuracy = 77.6%
# Precision = 73.9%
# TPR or Recall = 97.1%
# FNR = 2.9%
# FPR = 52.2%

# %% [markdown]
# ### Forward stepwise with all interaction terms

# %%
X = train[['Temperature','Rain','Ws','RH','FFMC','DMC','DC','ISI','BUI','FWI']]

X_backup = train[['Temperature','Rain','Ws','RH','FFMC','DMC','DC','ISI','BUI','FWI']]

# %%
for combo in itertools.combinations(X_backup.columns, 2):    
    train['_'.join(combo)] = train[combo[0]]*train[combo[1]] # creating int. terms
    test['_'.join(combo)] = test[combo[0]]*test[combo[1]] # creating int, terms
    X.loc[:,'_'.join(combo)] = train.loc[:,'_'.join(combo)] # creating the same x

# %%
models_best = forward_selection()
# Out:
# Processed  55 models on 1 predictors in 0.15278077125549316 seconds.
# Processed  54 models on 2 predictors in 0.13736200332641602 seconds.
# Processed  53 models on 3 predictors in 0.1709918975830078 seconds.
# Processed  52 models on 4 predictors in 0.19387197494506836 seconds.
# Processed  51 models on 5 predictors in 0.21823406219482422 seconds.
# Processed  50 models on 6 predictors in 0.23644804954528809 seconds.
# Processed  49 models on 7 predictors in 0.2611100673675537 seconds.
# Processed  48 models on 8 predictors in 0.2800321578979492 seconds.
# Processed  47 models on 9 predictors in 0.29959917068481445 seconds.
# Processed  46 models on 10 predictors in 0.469404935836792 seconds.
# Processed  45 models on 11 predictors in 0.34943389892578125 seconds.
# Processed  44 models on 12 predictors in 0.38717198371887207 seconds.
# Processed  43 models on 13 predictors in 0.40163397789001465 seconds.
# Processed  42 models on 14 predictors in 0.4110567569732666 seconds.
# Processed  41 models on 15 predictors in 0.411884069442749 seconds.
# Processed  40 models on 16 predictors in 0.43920111656188965 seconds.
# Processed  39 models on 17 predictors in 0.41977405548095703 seconds.
# Processed  38 models on 18 predictors in 0.4733767509460449 seconds.
# Processed  37 models on 19 predictors in 0.4678373336791992 seconds.
# Processed  36 models on 20 predictors in 0.4436008930206299 seconds.
# Processed  35 models on 21 predictors in 0.5642340183258057 seconds.
# Processed  34 models on 22 predictors in 0.4595510959625244 seconds.
# Processed  33 models on 23 predictors in 0.4490530490875244 seconds.
# Processed  32 models on 24 predictors in 0.47856593132019043 seconds.
# Processed  31 models on 25 predictors in 0.4833250045776367 seconds.
# Processed  30 models on 26 predictors in 0.46338415145874023 seconds.
# Processed  29 models on 27 predictors in 0.46733999252319336 seconds.
# Processed  28 models on 28 predictors in 0.4779679775238037 seconds.
# Processed  27 models on 29 predictors in 0.4777960777282715 seconds.
# Processed  26 models on 30 predictors in 0.5529887676239014 seconds.
# Processed  25 models on 31 predictors in 0.44474315643310547 seconds.
# Processed  24 models on 32 predictors in 0.4747331142425537 seconds.
# Processed  23 models on 33 predictors in 0.48056912422180176 seconds.
# Processed  22 models on 34 predictors in 0.44058704376220703 seconds.
# Processed  21 models on 35 predictors in 0.42122697830200195 seconds.
# Processed  20 models on 36 predictors in 0.41493892669677734 seconds.
# Processed  19 models on 37 predictors in 0.42923593521118164 seconds.
# Processed  18 models on 38 predictors in 0.39827799797058105 seconds.
# Processed  17 models on 39 predictors in 0.38162684440612793 seconds.
# Processed  16 models on 40 predictors in 0.36952877044677734 seconds.
# Processed  15 models on 41 predictors in 0.45365190505981445 seconds.
# Processed  14 models on 42 predictors in 0.34533095359802246 seconds.
# Processed  13 models on 43 predictors in 0.3404421806335449 seconds.
# Processed  12 models on 44 predictors in 0.3120250701904297 seconds.
# Processed  11 models on 45 predictors in 0.29914426803588867 seconds.
# Processed  10 models on 46 predictors in 0.27184295654296875 seconds.
# Processed  9 models on 47 predictors in 0.26971888542175293 seconds.
# Processed  8 models on 48 predictors in 0.23606109619140625 seconds.
# Processed  7 models on 49 predictors in 0.2083907127380371 seconds.
# Processed  6 models on 50 predictors in 0.18005728721618652 seconds.
# Processed  5 models on 51 predictors in 0.15546798706054688 seconds.
# Processed  4 models on 52 predictors in 0.12642979621887207 seconds.
# Processed  3 models on 53 predictors in 0.10000872611999512 seconds.
# Processed  2 models on 54 predictors in 0.06909823417663574 seconds.
# Processed  1 models on 55 predictors in 0.03502011299133301 seconds.
# Total elapsed time: 19.26814103126526 seconds.

# %%
best_sub_plots()

# %%
# Optimizing for AIC because we want a more aggressive model

best_fwd_reg_model_AIC = models_best['model'][35]
best_fwd_reg_model_AIC.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Classes   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     49.56
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):           7.26e-61
# Time:                        15:14:49   Log-Likelihood:                 102.62
# No. Observations:                 170   AIC:                            -133.2
# Df Residuals:                     134   BIC:                            -20.34
# Df Model:                          35
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.4329      0.970     -0.446      0.656      -2.351       1.485
# RH_ISI               0.0100      0.002      4.709      0.000       0.006       0.014
# ISI_FWI              0.0031      0.004      0.850      0.397      -0.004       0.010
# ISI                 -2.4598      0.562     -4.380      0.000      -3.571      -1.349
# DMC_ISI              0.0038      0.005      0.706      0.481      -0.007       0.014
# Temperature_Ws       0.0021      0.002      1.214      0.227      -0.001       0.005
# Rain_FWI            -0.0238      0.064     -0.372      0.710      -0.151       0.103
# RH                  -0.0004      0.016     -0.026      0.979      -0.031       0.030
# Rain_DC              0.0006      0.003      0.230      0.818      -0.005       0.006
# Ws_FWI               0.0020      0.002      0.953      0.342      -0.002       0.006
# Rain_Ws          -9.792e-05      0.002     -0.058      0.954      -0.003       0.003
# Rain_ISI             0.1046      0.083      1.262      0.209      -0.059       0.268
# FFMC                 0.0447      0.012      3.812      0.000       0.021       0.068
# RH_DMC               0.0003      0.000      0.930      0.354      -0.000       0.001
# Ws_FFMC             -0.0023      0.001     -3.767      0.000      -0.004      -0.001
# Temperature         -0.0015      0.033     -0.044      0.965      -0.067       0.064
# Temperature_Rain     0.0048      0.004      1.230      0.221      -0.003       0.013
# Temperature_DC      -0.0028      0.001     -3.464      0.001      -0.004      -0.001
# Ws_RH                0.0011      0.000      2.801      0.006       0.000       0.002
# Temperature_BUI      0.0242      0.008      3.024      0.003       0.008       0.040
# DMC_BUI              0.0019      0.000      4.014      0.000       0.001       0.003
# DMC_FWI             -0.0032      0.003     -1.100      0.273      -0.009       0.003
# FWI                  3.4068      0.410      8.304      0.000       2.595       4.218
# FFMC_FWI            -0.0308      0.004     -7.891      0.000      -0.038      -0.023
# FFMC_BUI            -0.0109      0.004     -3.073      0.003      -0.018      -0.004
# FFMC_DC              0.0016      0.000      4.487      0.000       0.001       0.002
# FFMC_ISI             0.0198      0.005      3.758      0.000       0.009       0.030
# Temperature_DMC     -0.0180      0.007     -2.710      0.008      -0.031      -0.005
# RH_FWI              -0.0075      0.002     -4.831      0.000      -0.011      -0.004
# BUI_FWI             -0.0015      0.001     -1.182      0.239      -0.004       0.001
# DC                  -0.0533      0.016     -3.317      0.001      -0.085      -0.022
# RH_DC                0.0003   9.21e-05      3.507      0.001       0.000       0.001
# Temperature_RH      -0.0008      0.000     -2.049      0.042      -0.002   -2.88e-05
# FFMC_DMC             0.0069      0.003      2.293      0.023       0.001       0.013
# Ws_DC               -0.0005      0.000     -1.821      0.071      -0.001    4.52e-05
# Rain_FFMC           -0.0039      0.003     -1.565      0.120      -0.009       0.001
# ==============================================================================
# Omnibus:                       21.961   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.760
# Skew:                          -0.432   Prob(JB):                     5.25e-15
# Kurtosis:                       5.922   Cond. No.                     7.77e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
confusion_matrix_data(train, train.Classes, best_fwd_reg_model_AIC, 0.3)
# Out:
# Classification accuracy = 94.8%
# Precision = 91.7%
# TPR or Recall = 100.0%
# FNR = 0.0%
# FPR = 12.2%

# %%
confusion_matrix_data(test, test.Classes, best_fwd_reg_model_AIC, 0.3)
# Out:
# Classification accuracy = 80.0%
# Precision = 71.0%
# TPR or Recall = 95.7%
# FNR = 4.3%
# FPR = 33.3%

# %% [markdown]
# ## Forward Stepwise with just some of the variables as interaction terms

# %%
X = train[['FFMC', 'FWI', 'RH', 'BUI', 'Ws', 'Rain']]

X_backup = train[['FFMC', 'FWI', 'RH', 'BUI', 'Ws', 'Rain']]

for combo in itertools.combinations(X_backup.columns, 2):    
    train['_'.join(combo)] = train[combo[0]]*train[combo[1]] # creating int. terms
    test['_'.join(combo)] = test[combo[0]]*test[combo[1]] # creating int, terms
    X.loc[:,'_'.join(combo)] = train.loc[:,'_'.join(combo)] # creating the same x

# %%
models_best = forward_selection()
# Out:
# Processed  21 models on 1 predictors in 0.08901810646057129 seconds.
# Processed  20 models on 2 predictors in 0.060736894607543945 seconds.
# Processed  19 models on 3 predictors in 0.05917692184448242 seconds.
# Processed  18 models on 4 predictors in 0.06736111640930176 seconds.
# Processed  17 models on 5 predictors in 0.07495403289794922 seconds.
# Processed  16 models on 6 predictors in 0.07532215118408203 seconds.
# Processed  15 models on 7 predictors in 0.08454108238220215 seconds.
# Processed  14 models on 8 predictors in 0.08656573295593262 seconds.
# Processed  13 models on 9 predictors in 0.08666491508483887 seconds.
# Processed  12 models on 10 predictors in 0.08340239524841309 seconds.
# Processed  11 models on 11 predictors in 0.09149813652038574 seconds.
# Processed  10 models on 12 predictors in 0.08972501754760742 seconds.
# Processed  9 models on 13 predictors in 0.07717609405517578 seconds.
# Processed  8 models on 14 predictors in 0.07828807830810547 seconds.
# Processed  7 models on 15 predictors in 0.06903600692749023 seconds.
# Processed  6 models on 16 predictors in 0.06960701942443848 seconds.
# Processed  5 models on 17 predictors in 0.06531405448913574 seconds.
# Processed  4 models on 18 predictors in 0.05159807205200195 seconds.
# Processed  3 models on 19 predictors in 0.03892993927001953 seconds.
# Processed  2 models on 20 predictors in 0.02715015411376953 seconds.
# Processed  1 models on 21 predictors in 0.013969182968139648 seconds.
# Total elapsed time: 1.4703960418701172 seconds.

# %%
best_sub_plots()

# %%
best_fwd_reg_model_AIC_some = models_best['model'][13]
best_fwd_reg_model_AIC_some.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Classes   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     77.01
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):           6.68e-61
# Time:                        15:18:34   Log-Likelihood:                 48.950
# No. Observations:                 170   AIC:                            -69.90
# Df Residuals:                     156   BIC:                            -26.00
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.6334      0.982     -3.701      0.000      -5.573      -1.694
# FFMC           0.0610      0.012      4.975      0.000       0.037       0.085
# FWI_RH        -0.0009      0.000     -1.782      0.077      -0.002    9.35e-05
# BUI_Ws         0.0004      0.001      0.761      0.448      -0.001       0.001
# FWI_Rain       0.0365      0.010      3.770      0.000       0.017       0.056
# RH             0.0277      0.013      2.077      0.039       0.001       0.054
# FFMC_RH       -0.0004      0.000     -2.619      0.010      -0.001   -9.62e-05
# FFMC_FWI      -0.0132      0.002     -6.526      0.000      -0.017      -0.009
# FWI            1.3313      0.211      6.313      0.000       0.915       1.748
# FFMC_Ws       -0.0013      0.000     -4.341      0.000      -0.002      -0.001
# BUI           -0.1546      0.035     -4.409      0.000      -0.224      -0.085
# RH_Ws          0.0009      0.000      2.995      0.003       0.000       0.001
# FFMC_BUI       0.0012      0.000      3.343      0.001       0.000       0.002
# RH_BUI         0.0003      0.000      2.140      0.034    2.53e-05       0.001
# ==============================================================================
# Omnibus:                        7.989   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):               13.875
# Skew:                          -0.144   Prob(JB):                     0.000971
# Kurtosis:                       4.370   Cond. No.                     3.69e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
confusion_matrix_data(train, train.Classes, best_fwd_reg_model_AIC_some, 0.3)
# Out:
# Classification accuracy = 94.3%
# Precision = 90.6%
# TPR or Recall = 100.0%
# FNR = 0.0%
# FPR = 12.5%

# %%
confusion_matrix_data(test, test.Classes, best_fwd_reg_model_AIC_some, 0.3)
# Out:
# Classification accuracy = 81.5%
# Precision = 73.7%
# TPR or Recall = 100.0%
# FNR = 0.0%
# FPR = 38.5%

# %% [markdown]
# ### Trying all of the variables

# %%
logit_model = smf.logit(formula = 'Classes~Temperature+Rain+Ws+RH+FFMC+DMC+DC+ISI+BUI+FWI', data = train).fit(method='bfgs')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 35
#          Gradient evaluations: 35

# %%
print(logit_model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Classes   No. Observations:                  170
# Model:                          Logit   Df Residuals:                      159
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 27 Feb 2023   Pseudo R-squ.:                   1.000
# Time:                        15:08:45   Log-Likelihood:            -4.1286e-05
# converged:                       True   LL-Null:                       -115.84
# Covariance Type:            nonrobust   LLR p-value:                 3.821e-44
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -4.5916    1.9e+05  -2.42e-05      1.000   -3.73e+05    3.73e+05
# Temperature   -13.6444   1.44e+04     -0.001      0.999   -2.83e+04    2.83e+04
# Rain           12.4549   1.08e+04      0.001      0.999   -2.13e+04    2.13e+04
# Ws            -14.2500    1.2e+04     -0.001      0.999   -2.35e+04    2.35e+04
# RH             -0.1756   2371.822   -7.4e-05      1.000   -4648.862    4648.511
# FFMC            6.9864   1.22e+04      0.001      1.000   -2.38e+04    2.38e+04
# DMC            -5.5075   1.82e+04     -0.000      1.000   -3.57e+04    3.57e+04
# DC             -1.7615   4680.443     -0.000      1.000   -9175.262    9171.739
# ISI            20.5372   2.09e+05   9.82e-05      1.000    -4.1e+05     4.1e+05
# BUI             6.9381   4.87e+04      0.000      1.000   -9.54e+04    9.54e+04
# FWI            23.0895   1.21e+05      0.000      1.000   -2.38e+05    2.38e+05
# ===============================================================================
#
# Complete Separation: The results show that there iscomplete separation.
# In this case the Maximum Likelihood Estimator does not exist and the parameters
# are not identified.

# %%
confusion_matrix_data(train, train.Classes, logit_model, 0.3)
# Out:
# Classification accuracy = 100.0%
# Precision = 100.0%
# TPR or Recall = 100.0%
# FNR = 0.0%
# FPR = 0.0%

# %%
confusion_matrix_data(test, test.Classes, logit_model, 0.3)
# Out:
# Classification accuracy = 90.4%
# Precision = 94.4%
# TPR or Recall = 87.2%
# FNR = 12.8%
# FPR = 5.9%

# %% [markdown]
# ## Binning to see if transformations are necessary among variables

# %%
variables = ['Temperature','Rain','Ws','RH','FFMC','DMC','DC','ISI','BUI','FWI']

fig, axes = plt.subplots(5,2,figsize=(30,30))

var = 0

for i in range(5):
    for j in range(2):
        
        # Binning var
        binned = pd.qcut(train[variables[var]], 11, retbins = True, duplicates = 'drop')
        train['Binned'] = binned[0]
        
        data = train.groupby('Binned')['Classes'].agg([('fire_percent','mean'),('nobs','count')]).reset_index(drop=False)
        
        label = variables[var] + ' bin'
        axes[i,j].set_xlabel(label)
        
        
        sns.lineplot(ax = axes[i,j], x = data.index, y= data['fire_percent'])
        
        var += 1

# %% [markdown]
# No transformations necessary

# %% [markdown]
# Final Models (optimizing for recall):
#
# 1. best_fwd_reg_model_AIC_some
# 2. best_fwd_reg_model_AIC
# 3. best_subset_model_no_interaction
# 4. logit_model

# %% [markdown]
# # Model Evaluation (Abenezer)

# %% [markdown]
# - ROC-AUC
# - Confusion Matrix
# - Precision, recall, that sort of thing
# -
